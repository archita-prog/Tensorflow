# %%
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize = 14):
    df_cm = pd.DataFrame(
        confusion_matrix, index = class_names, columns = class_names,
    )
    fig = plt.figure(figsize= figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot = True, fmt = "d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotations = 0, has = 'right', fontsize = fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotations = 45, ha = 'right', fontsize = fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
truth = ["Dog", "Not a dog","Dog", "Dog",  "Dog", "Not a dog", "Dog",   "Dog","Not a dog"]
prediction = ["Dog,", "Dog",   "Dog", "Not a dog", "Dog",  "Not a dog","Dog","Dog"]

# %%
print(len(truth))       # Number of true labels
print(len(prediction))  # Number of predicted labels
# Out:
# 9
# 8

# %%
min_len = min(len(truth), len(prediction))
truth = truth[:min_len]
prediction = prediction[:min_len]

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(truth, prediction)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(truth, prediction)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[4 1 1]
#  [0 0 0]
#  [1 0 1]]

# %%
print(cm.shape)  # This should print (3, 3)
# Out:
# (3, 3)

# %%
labels = ["Dog", "Not a dog", "Unknown"]  # Adjust these to match your classes

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(truth, prediction))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.80      0.67      0.73         6
#         Dog,       0.00      0.00      0.00         0
#    Not a dog       0.50      0.50      0.50         2
#
#     accuracy                           0.62         8
#    macro avg       0.43      0.39      0.41         8
# weighted avg       0.73      0.62      0.67         8
# C:\Users\Archita Shrivastava\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Archita Shrivastava\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
