# %%
import tensorflow as tf

# %%
daily_sales_numbers = [21, 22, -108, 31, -1, 32, 34, 31]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)
tf_dataset
# Out:
# <_TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
for sales in tf_dataset:
    print(sales.numpy())
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %%
for sales in tf_dataset.take(3):
    print(sales.numpy())
# Out:
# 21
# 22
# -108

# %%
tf_dataset = tf_dataset.filter(lambda x: x >0)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# 31
# 32
# 34
# 31

# %%
tf_dataset = tf_dataset.map(lambda x: x*72)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 1512
# 1584
# 2232
# 2304
# 2448
# 2232

# %%
tf_dataset = tf_dataset.shuffle(3)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 1512
# 2232
# 2304
# 1584
# 2232
# 2448

# %%
for sales_batch in tf_dataset.batch(4):
    print(sales_batch.numpy())
# Out:
# [1512 2232 2304 2232]
# [1584 2448]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)
tf_dataset = tf_dataset.filter(lambda x: x>0).map(lambda x: x*72).shuffle(2).batch(2)

for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000190B44DD7E0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x00000190B44DD7E0>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 72
#
# Match 1:
# lambda x: x > 0
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000190B44DD7E0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x00000190B44DD7E0>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 72
#
# Match 1:
# lambda x: x > 0
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000190DECBA050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x00000190DECBA050>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 72
#
# Match 1:
# lambda x: x > 0
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000190DECBA050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x00000190DECBA050>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 72
#
# Match 1:
# lambda x: x > 0
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [1584 2232]
# [1512 2448]
# [2232 2304]
